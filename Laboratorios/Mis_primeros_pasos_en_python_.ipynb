# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Sesión 01
# ## Fundamentos de ciencia de datos
#
# **Primeros pasos en python**

# %%
# Importar librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Crear un arreglo con numpy
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
# Guardar o asignar un arreglo
arreglo = np.array([1,2,3,4,5])

# %%
# Imprimir
print(arreglo)
# Out:
# [1 2 3 4 5]

# %%
# Imprimir
arreglo
# Out:
# array([1, 2, 3, 4, 5])

# %%
# crear un arreglo 2
ejemplo2= np.array([25,21,24,26])

# %%
ejemplo2
# Out:
# array([25, 21, 24, 26])

# %%
# Crear una matriz con numpy
matriz_ejemplo = np.array([[1,3,5],
                          [7,9,11]])

# %%
matriz_ejemplo
# Out:
# array([[ 1,  3,  5],
#        [ 7,  9, 11]])

# %% [markdown]
# # Data frame (conjunto de datos)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Cargar conjunto de datos
# Forma 1
caso_telefonia = pd.read_csv("/content/Caso_telefonia.csv", encoding="latin1",
                             sep=";")

# %%
# Mostrar los primeros registros
caso_telefonia.head()
# Out:
#    Género  Edad  Llamadas  Minutos  Monto facturado  Tiempo de espera  \
# 0       1    27         7     33.0             90.7              16.9
# 1       0    28         4     31.7             95.7               1.5
# 2       0    24         9     31.4             99.3               2.8
# 3       1    33         5     26.9             83.3               4.6
# 4       1    21         4     35.5             97.3               3.5
#
#      Opinión   Sucursal
# 0    Regular  Suc. Este
# 1      Bueno  Suc. Este
# 2     Pésimo  Suc. Este
# 3     Pésimo  Suc. Este
# 4  Excelente  Suc. Este

# %%
# Cargar conjunto de datos
# Forma 2
caso_telefonia_2 = pd.read_csv("/content/Caso_telefonia.csv", encoding="latin1",
                             sep=";")
# Mostrar los primeros registros
display(caso_telefonia_2.head())
# Out:
#    Género  Edad  Llamadas  Minutos  Monto facturado  Tiempo de espera  \
# 0       1    27         7     33.0             90.7              16.9
# 1       0    28         4     31.7             95.7               1.5
# 2       0    24         9     31.4             99.3               2.8
# 3       1    33         5     26.9             83.3               4.6
# 4       1    21         4     35.5             97.3               3.5
#
#      Opinión   Sucursal
# 0    Regular  Suc. Este
# 1      Bueno  Suc. Este
# 2     Pésimo  Suc. Este
# 3     Pésimo  Suc. Este
# 4  Excelente  Suc. Este

# %%
# Conectarse con drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cargar de datos forma 3
caso_telefonia2 =pd.read_csv("/content/drive/MyDrive/2025/Sesion1/Caso_telefonia.csv", encoding="latin1",
                             sep=";")

# %%
# Mostrar los registros
caso_telefonia2.head()
# Out:
#    Género  Edad  Llamadas  Minutos  Monto facturado  Tiempo de espera  \
# 0       1    27         7     33.0             90.7              16.9
# 1       0    28         4     31.7             95.7               1.5
# 2       0    24         9     31.4             99.3               2.8
# 3       1    33         5     26.9             83.3               4.6
# 4       1    21         4     35.5             97.3               3.5
#
#      Opinión   Sucursal
# 0    Regular  Suc. Este
# 1      Bueno  Suc. Este
# 2     Pésimo  Suc. Este
# 3     Pésimo  Suc. Este
# 4  Excelente  Suc. Este

# %%
pip install pyreadstat
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 666.4/666.4 kB 13.5 MB/s eta 0:00:00
# ...

# %%
import pyreadstat

# %%
# Cargar carchivo SPSS
telefonia_spss = pd.read_spss("/content/drive/MyDrive/2025/Sesion1/Caso_telefonia.sav")

# %%
telefonia_spss.head()
# Out:
#       Género  Edad  Llamadas  Minutos  Montofacturado  Tiempodeespera  \
# 0  Masculino  27.0       7.0     33.0            90.7            16.9
# 1   Femenino  28.0       4.0     31.7            95.7             1.5
# 2   Femenino  24.0       9.0     31.4            99.3             2.8
# 3  Masculino  33.0       5.0     26.9            83.3             4.6
# 4  Masculino  21.0       4.0     35.5            97.3             3.5
#
#      Opinión   Sucursal
# 0    Regular  Suc. Este
# 1      Bueno  Suc. Este
# 2     Pésimo  Suc. Este
# 3     Pésimo  Suc. Este
# 4  Excelente  Suc. Este

# %%
# Cargar desde excel
telefonia_excel = pd.read_excel("/content/drive/MyDrive/2025/Sesion1/Caso_telefonia.xlsx")

# %%
# mostrar
telefonia_excel.head()
# Out:
#    Género  Edad  Llamadas  Minutos  Monto facturado  Tiempo de espera  \
# 0       1    27         7     33.0             90.7              16.9
# 1       0    28         4     31.7             95.7               1.5
# 2       0    24         9     31.4             99.3               2.8
# 3       1    33         5     26.9             83.3               4.6
# 4       1    21         4     35.5             97.3               3.5
#
#      Opinión   Sucursal
# 0    Regular  Suc. Este
# 1      Bueno  Suc. Este
# 2     Pésimo  Suc. Este
# 3     Pésimo  Suc. Este
# 4  Excelente  Suc. Este

# %%
# Cargar archivos desde fuente GITHUB.COM
merketing_directo = pd.read_csv("https://raw.githubusercontent.com/VictorGuevaraP/ME-Machine-Learning/refs/heads/master/MarketingDirecto_mi.csv",
                                sep=";")

# %%
merketing_directo.head()
# Out:
#      Edad     Genero   Vivienda   Ecivil Ubicacion  Salario  Hijos Historial  \
# 0  Adulta   Femenino     Propia  Soltero     Lejos  47500.0      0      Alto
# 1   Media  Masculino  Alquilada  Soltero     Cerca  63600.0      0      Alto
# 2   Joven   Femenino  Alquilada  Soltero     Cerca  13500.0      0      Bajo
# 3   Media  Masculino     Propia   Casado     Cerca  85600.0      1      Alto
# 4   Media   Femenino     Propia  Soltero     Cerca  68400.0      0      Alto
#
#    Catalogos  Monto
# 0          6    755
# 1          6   1318
# 2         18    296
# 3         18   2436
# 4         12   1304

# %%
# libreria opendatasets
# !pip install opendatasets #(conda)

# %%
import opendatasets as opd

# %%
# Obtener datos desde Kaggle
opd.download_kaggle_dataset("https://www.kaggle.com/datasets/mashlyn/online-retail-ii-uci?select=online_retail_II.csv",
                            "/content/drive/MyDrive/2025/Sesion1")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: 1
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/mashlyn/online-retail-ii-uci
# ...
# 100%|██████████| 14.5M/14.5M [00:00<00:00, 282MB/s]

# %% [markdown]
# # Actividad

# %% [markdown]
# Ingresar a github: https://github.com/VICTORGUEVARAP
#       Unicar el conjunto de datos cancer: https://github.com/VictorGuevaraP/ME-Machine-Learning/blob/master/cancer.csv
#
#       y cargarlo a su entorno de trabajo, mostrar los 5 primeros registros

# %% [markdown]
# Ingresa a kaggle: https://www.kaggle.com/
#
# * ubicar cualquier conjunto de datos de interes y cargarlo a su entorno de trabajo, mostrar los 5 primeros registros
